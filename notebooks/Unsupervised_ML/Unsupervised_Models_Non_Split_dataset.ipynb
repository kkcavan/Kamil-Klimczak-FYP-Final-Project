# %%
import numpy as np
from numpy import ma
import pandas as pd
import math
from sklearn import metrics, linear_model
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.colors as colors
# %matplotlib inline
from matplotlib import ticker, cm
from matplotlib.pyplot import figure
import seaborn as sns

from scipy.stats import multivariate_normal
from sklearn.metrics import f1_score, confusion_matrix, classification_report, precision_recall_fscore_support
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.neighbors import LocalOutlierFactor
from sklearn.ensemble import IsolationForest
from sklearn.covariance import EllipticEnvelope
from sklearn.svm import OneClassSVM

import tensorflow as tf
from sklearn.metrics import precision_recall_curve, average_precision_score, auc
from keras.models import Model
from keras.layers import Input, Dense
from keras.callbacks import ModelCheckpoint, TensorBoard
from keras import regularizers
import os
from sklearn.ensemble import IsolationForest
from sklearn.metrics import f1_score, balanced_accuracy_score, roc_auc_score, precision_recall_fscore_support
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.metrics import average_precision_score, matthews_corrcoef
from sklearn.metrics import f1_score, balanced_accuracy_score, roc_auc_score, precision_recall_fscore_support
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Import Data

# %%
print(os.getcwd())
relative_path = os.path.abspath(os.path.join(os.getcwd(), "../../"))
data = pd.read_csv(relative_path+'/preprocessed_data/non_split_dataset/total_subset.csv')
data = data.drop(['evil'],axis=1)
print(data.shape)
# Out:
# a:\Desktop\FYP Final Files\notebooks\Unsupervised_ML
# (1141078, 8)

# %%
#X = data.drop(['sus'],axis=1)
X = data
y = data['sus']

# %% [markdown]
# # Helpers

# %%
def split_data(df: pd.DataFrame) -> pd.DataFrame:
    features = df[["processId", "parentProcessId", "userId", "mountNamespace", "eventId", "argsNum", "returnValue"]]
    labels = df['sus']
    return features, labels

# %%
def print_metrics(y_true, y_predicted):

    accuracy = accuracy_score(y_true, y_predicted)   
    metrics_results = precision_recall_fscore_support(y_true, y_predicted, average="weighted", pos_label=1)
    average_precision = average_precision_score(y_true, y_predicted)
    balanced_accuracy = balanced_accuracy_score(y_true, y_predicted)
    mcc = matthews_corrcoef(y_true, y_predicted)
    
    print(f'Accuracy:\t{accuracy:.3f}')
    print(f'Precision:\t{metrics_results[0]}')
    print(f'Recall:\t\t{metrics_results[1]:.3f}')
    print(f'F1-Score:\t{metrics_results[2]:.3f}')
    print("Average Precision Score:", average_precision)
    print("Balanced Accuracy Score:", balanced_accuracy)
    print("Matthews Correlation Coefficient (MCC):", mcc)
    print('AUC : {0:0.5f}'.format(metrics.roc_auc_score(y_true , y_predicted)))
    
    #make confusion matrix
    confusion_matrixs = confusion_matrix(y_true, y_predicted)
    

    TP = confusion_matrixs[1][1]
    TN = confusion_matrixs[0][0]
    FP = confusion_matrixs[0][1]
    FN = confusion_matrixs[1][0]


    plt.figure(figsize=(8, 6))
    sns.heatmap(confusion_matrixs, annot=True, fmt='d', cmap='Blues')
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.title('Confusion Matrix')
    plt.show()

    print("True Positives (TP):", TP)
    print("True Negatives (TN):", TN)
    print("False Positives (FP):", FP)
    print("False Negatives (FN):", FN)

    # Print roc curve
    fpr, tpr, thresholds = metrics.roc_curve(y_true, y_predicted)
    roc_auc = metrics.auc(fpr, tpr)
    display = metrics.RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc=roc_auc, )
    display.plot()
    plt.show()


    # Assuming test_df_labels is your true labels and mse_test contains continuous score values
    precision, recall, _ = precision_recall_curve(y_true, y_predicted)

    # Calculate the area under the curve
    pr_auc = auc(recall, precision)

    # Plotting
    plt.figure(figsize=(8, 6))
    plt.plot(recall, precision, label=f'Precision-Recall curve (area = {pr_auc:.2f})')
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.title('Precision-Recall Curve')
    plt.legend(loc='best')
    plt.show()

# %%
def benign_accuracy(values):
    
    tp=list(values).count(1)
    total=values.shape[0]
    accuracy=np.round(tp/total,4)
    
    return accuracy

def sus_accuracy(values):
    
    tn=list(values).count(-1)
    total=values.shape[0]
    accuracy=np.round(tn/total,4)
    
    return accuracy

# %%
def prepare_labels(y_predicted):
    """
    Helper function to help map out the outputs from models that return -1 for outliers and 1 for inliners.
    """
    y_predicted[y_predicted == 1] = 0
    y_predicted[y_predicted == -1] = 1
    return y_predicted

# %% [markdown]
# # Split data

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, shuffle=True, random_state=0)

# %%
X_train = X_train[X_train['sus']==0]
X_train = X_train.drop(columns='sus')
X_test = X_test.drop(columns='sus')

# %%
X_train.head()
# Out:
#          processId  parentProcessId  userId  mountNamespace  eventId  argsNum  \
# 335256           1                1       0               0     1005        4
# 1043942          1                1       0               0     1005        4
# 1028670          1                1       0               1        5        2
# 674605           1                1       0               0        3        1
# 714299           1                1       0               0     1005        4
#
#          returnValue
# 335256             0
# 1043942            0
# 1028670            0
# 674605             0
# 714299             0

# %% [markdown]
# # Model training

# %% [markdown]
# ## Isolation forest

# %%
iforest = IsolationForest(random_state=0,contamination=0.05)
iforest.fit(X_train)
# Out:
# IsolationForest(contamination=0.05, random_state=0)

# %%
ypred_iforest = iforest.predict(X_test)
ypred_iforest = prepare_labels(ypred_iforest)
print(classification_report(y_test, ypred_iforest,digits=3))
# Out:
#               precision    recall  f1-score   support
#
#            0      0.973     0.952     0.962    193389
#            1      0.760     0.851     0.803     34827
#
#     accuracy                          0.936    228216
#    macro avg      0.866     0.902     0.883    228216
# weighted avg      0.940     0.936     0.938    228216

# %%
print_metrics(y_test,ypred_iforest)
# Out:
# Accuracy:	0.936
# Precision:	0.9401921389078381
# Recall:		0.936
# F1-Score:	0.938
# Average Precision Score: 0.6697156976032888
# Balanced Accuracy Score: 0.9015005248199272
# Matthews Correlation Coefficient (MCC): 0.7669912723565727
# AUC : 0.90150
# True Positives (TP): 29653
# True Negatives (TN): 184022
# False Positives (FP): 9367
# False Negatives (FN): 5174

# %% [markdown]
# ## Local Outlier Factor

# %%
lof = LocalOutlierFactor(contamination=0.05, novelty=True)
lof.fit(X_train)
# Out:
# LocalOutlierFactor(contamination=0.05, novelty=True)

# %%
predicted_scores = lof.decision_function(X_test)
predicted_labels = lof.predict(X_test)
predicted_labels = (predicted_labels == -1).astype(int)
# Out:
# c:\Users\Kamil\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LocalOutlierFactor was fitted with feature names
#   warnings.warn(
# c:\Users\Kamil\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LocalOutlierFactor was fitted with feature names
#   warnings.warn(

# %%
print(classification_report(y_test, predicted_labels))
print_metrics(y_test,predicted_labels)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99    193389
#            1       1.00      0.94      0.97     34827
#
#     accuracy                           0.99    228216
#    macro avg       0.99      0.97      0.98    228216
# weighted avg       0.99      0.99      0.99    228216
#
# Accuracy:	0.991
# Precision:	0.9908858456382486
# Recall:		0.991
# F1-Score:	0.991
# Average Precision Score: 0.9486677440727171
# Balanced Accuracy Score: 0.9708997719069783
# Matthews Correlation Coefficient (MCC): 0.9642208318742908
# AUC : 0.97090
# True Positives (TP): 32815
# True Negatives (TN): 193306
# False Positives (FP): 83
# False Negatives (FN): 2012

# %% [markdown]
# ## SVM

# %%
model = linear_model.SGDOneClassSVM(random_state=0).fit(X_train)

# %%
y_pred_svm = model.predict(X_test)
y_pred_svm = prepare_labels(y_pred_svm)
print(classification_report(y_test,y_pred_svm))
print_metrics(y_test,y_pred_svm)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.71      0.75    193389
#            1       0.02      0.04      0.03     34827
#
#     accuracy                           0.61    228216
#    macro avg       0.41      0.37      0.39    228216
# weighted avg       0.68      0.61      0.64    228216
#
# Accuracy:	0.609
# Precision:	0.6849833555113135
# Recall:		0.609
# F1-Score:	0.644
# Average Precision Score: 0.14767852060261066
# Balanced Accuracy Score: 0.3747035121645893
# Matthews Correlation Coefficient (MCC): -0.20799376300519612
# AUC : 0.37470
# True Positives (TP): 1326
# True Negatives (TN): 137564
# False Positives (FP): 55825
# False Negatives (FN): 33501

# %% [markdown]
# ## Autoenconder

# %%
from keras.models import Model
from keras.layers import Input, Dense
from keras.optimizers import Adam

input_dim = X_train.shape[1] # Number of features

# Encoder
input_layer = Input(shape=(input_dim, ))
encoder = Dense(128, activation="relu")(input_layer)
encoder = Dense(64, activation="relu")(encoder)

# Bottleneck
bottleneck = Dense(32, activation="relu")(encoder)

# Decoder
decoder = Dense(64, activation="relu")(bottleneck)
decoder = Dense(128, activation="relu")(decoder)
decoder = Dense(input_dim, activation="linear")(decoder)

autoencoder = Model(inputs=input_layer, outputs=decoder)
autoencoder.compile(optimizer=Adam(learning_rate=0.001), loss='mse')

# %%
from keras.callbacks import ModelCheckpoint

checkpoint = ModelCheckpoint("best_weights2.keras", monitor='val_loss', verbose=1, save_best_only=True, mode='min')

history = autoencoder.fit(
    X_train, X_train,
    epochs=20,
    batch_size=256,
    validation_data=(X_test, X_test),
    shuffle=True,
    callbacks=[checkpoint]
)
autoencoder.load_weights("best_weights2.keras")
# Out:
# Epoch 1/20
# 2988/3025 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 625.8610
# Epoch 1: val_loss improved from inf to 0.03059, saving model to best_weights2.keras
# 3025/3025 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 619.2034 - val_loss: 0.0306
# Epoch 2/20
# 3001/3025 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0539
# Epoch 2: val_loss did not improve from 0.03059
# 3025/3025 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0550 - val_loss: 0.0372
# Epoch 3/20
# 2998/3025 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4141
# Epoch 3: val_loss did not improve from 0.03059
# 3025/3025 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.4141 - val_loss: 0.0856
# Epoch 4/20
# 3018/3025 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3668
# Epoch 4: val_loss did not improve from 0.03059
# 3025/3025 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.3668 - val_loss: 0.0323
# Epoch 5/20
# 3014/3025 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3140
# Epoch 5: val_loss did not improve from 0.03059
# 3025/3025 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.3141 - val_loss: 0.0396
# Epoch 6/20
# 3002/3025 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2499
# Epoch 6: val_loss did not improve from 0.03059
# 3025/3025 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.2500 - val_loss: 0.1765
# Epoch 7/20
# 2995/3025 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3451
# Epoch 7: val_loss did not improve from 0.03059
# 3025/3025 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.3462 - val_loss: 0.0316
# Epoch 8/20
# 3001/3025 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0889
# Epoch 8: val_loss did not improve from 0.03059
# 3025/3025 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0898 - val_loss: 0.0332
# Epoch 9/20
# 2990/3025 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1261
# Epoch 9: val_loss did not improve from 0.03059
# 3025/3025 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.1269 - val_loss: 0.0548
# Epoch 10/20
# 3016/3025 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1542
# Epoch 10: val_loss did not improve from 0.03059
# 3025/3025 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.1543 - val_loss: 0.0351
# Epoch 11/20
# 3015/3025 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2393
# Epoch 11: val_loss did not improve from 0.03059
# 3025/3025 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.2392 - val_loss: 0.0436
# Epoch 12/20
# 3021/3025 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2680
# Epoch 12: val_loss did not improve from 0.03059
# 3025/3025 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.2679 - val_loss: 0.0313
# Epoch 13/20
# 2999/3025 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1624
# Epoch 13: val_loss did not improve from 0.03059
# 3025/3025 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.1626 - val_loss: 0.0310
# Epoch 14/20
# 3010/3025 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1894
# Epoch 14: val_loss did not improve from 0.03059
# 3025/3025 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.1892 - val_loss: 0.1637
# Epoch 15/20
# 3023/3025 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3151
# Epoch 15: val_loss improved from 0.03059 to 0.02558, saving model to best_weights2.keras
# 3025/3025 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.3150 - val_loss: 0.0256
# Epoch 16/20
# 3025/3025 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1417
# Epoch 16: val_loss did not improve from 0.02558
# 3025/3025 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.1417 - val_loss: 0.0799
# Epoch 17/20
# 3005/3025 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1325
# Epoch 17: val_loss did not improve from 0.02558
# 3025/3025 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.1326 - val_loss: 1.0314
# Epoch 18/20
# 2993/3025 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2364
# Epoch 18: val_loss did not improve from 0.02558
# 3025/3025 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.2356 - val_loss: 0.3653
# Epoch 19/20
# 3007/3025 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4554
# Epoch 19: val_loss did not improve from 0.02558
# 3025/3025 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.4537 - val_loss: 0.0274
# Epoch 20/20
# 2988/3025 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2221
# Epoch 20: val_loss did not improve from 0.02558
# 3025/3025 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.2219 - val_loss: 0.0431

# %%
# Predict on the test set
X_test_pred = autoencoder.predict(X_test)

X_train_pred = autoencoder.predict(X_train)
# Out:
# 7132/7132 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 24193/24193 ━━━━━━━━━━━━━━━━━━━━ 19s 791us/step

# %%
mse_train = np.mean(np.power(X_train - X_train_pred, 2), axis=1)
mse_test = np.mean(np.power(X_test - X_test_pred, 2), axis=1)

# %%
threshold = np.quantile(mse_train, 0.99)

# Predict anomalies on the test set
y_pred_test = (mse_test > threshold)
y_pred_test = y_pred_test.astype(int)

# %%
from sklearn.metrics import classification_report, roc_auc_score

# Calculate classification metrics
print(classification_report(y_test, y_pred_test))

# Calculate AUC-ROC
roc_auc = roc_auc_score(y_test, mse_test) # Using raw MSE scores for AUC calculation
print(f"AUC-ROC: {roc_auc:.2f}")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99    193389
#            1       0.95      0.94      0.95     34827
#
#     accuracy                           0.98    228216
#    macro avg       0.97      0.97      0.97    228216
# weighted avg       0.98      0.98      0.98    228216
#
# AUC-ROC: 0.97

# %%
print_metrics(y_test,y_pred_test)
# Out:
# Accuracy:	0.984
# Precision:	0.9835993635224008
# Recall:		0.984
# F1-Score:	0.984
# Average Precision Score: 0.904151935461839
# Balanced Accuracy Score: 0.9666110992455407
# Matthews Correlation Coefficient (MCC): 0.936575044986772
# AUC : 0.96661
# True Positives (TP): 32810
# True Negatives (TN): 191675
# False Positives (FP): 1714
# False Negatives (FN): 2017
